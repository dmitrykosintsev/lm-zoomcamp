# %% [markdown]
# ### Preparing files

# %% [markdown]
# All files can be found here:

# %% [markdown]
# ### Question 1. Probability of conversion

# %% [markdown]
# Output:
#
# `
# (.venv) [dmitry@Rog-zephyrus-g14 Homework 10]$ python3 q6_test.py`
#
# `{'conversion_probability': 0.49999999999842815, 'conversion': False}
# `

# %% [markdown]
# Answer 1: 0.49

# %% [markdown]
# ### Question 2. Version of kind

# %% [markdown]
# Output:
#
# `(.venv) [dmitry@Rog-zephyrus-g14 Homework 10]$ kind --version`
#
# `kind version 0.30.0`

# %% [markdown]
# Answer 2: 0.30.0

# %% [markdown]
# ### Question 3. Smallest deployable compute unit

# %% [markdown]
# Answer 3: pod

# %% [markdown]
# ### Question 4. Service type

# %% [markdown]
# Output:
#
# `(.venv) [dmitry@Rog-zephyrus-g14 Homework 10]$ sudo kubectl get services`
#
# `NAME         TYPE        CLUSTER-IP   EXTERNAL-IP   PORT(S)   AGE`
#
# `kubernetes   ClusterIP   10.96.0.1    <none>        443/TCP   3m23s`

# %% [markdown]
# Answer 4: ClusterIP

# %% [markdown]
# ### Question 5. Command

# %% [markdown]
# `(.venv) [dmitry@Rog-zephyrus-g14 Homework 10]$ sudo kind load docker-image zoomcamp-model:3.13.10-hw10 --name k8homework`
#
# `Image: "zoomcamp-model:3.13.10-hw10" with ID "sha256:60cb84d5868e3c9e9fed85f119a19f8dfd8cc99eb917f95dcbd0dc2a60ac47e2" not yet present on node "k8homework-control-plane", loading...`

# %% [markdown]
# Answer 5: kind load docker-image

# %% [markdown]
# ### Question 6. Port

# %% [markdown]
# Answer 6: 9696

# %% [markdown]
# ### Question 7. Service

# %% [markdown]
# Answer 7: subscription
