# %% [markdown]
# ## Unit 3. Classification

# %% [markdown]
# Churn prediction: analysing customer data to see which people might leave to stop them from going to our competitors

# %% [markdown]
# ### 3.1 Dataset

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %% [markdown]
# ### 3.2 Data preparation

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# Download data
data = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv'
#!wget $data -O 03-classification-data.csv

# %%
# Read the data
df = pd.read_csv('03-classification-data.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Transpose the dataset to see all columns - rows and columns change places
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
# Unifying the text for columns
df.columns = df.columns.str.lower().str.replace(' ', '_')
categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerid              7590-vhveg    5575-gnvde      3668-qpybk
# gender                      female          male            male
# seniorcitizen                    0             0               0
# partner                        yes            no              no
# dependents                      no            no              no
# tenure                           1            34               2
# phoneservice                    no           yes             yes
# multiplelines     no_phone_service            no              no
# internetservice                dsl           dsl             dsl
# onlinesecurity                  no           yes             yes
# onlinebackup                   yes            no             yes
# deviceprotection                no           yes              no
# techsupport                     no            no              no
# ...

# %%
# Check datatypes
df.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %%
# This column contains something that is not a number, that's why it is marked as an object in the previous output
pd.to_numeric(df.totalcharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "_"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # This column contains something that is not a number, that's why it is marked as an object in the previous output
# ----> 2 pd.to_numeric(df.totalcharges)
#
# File ~/Documents/Programming/Python/lm-zoomcamp/.venv/lib/python3.13/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
# ...

# %%
# Ignoring anything that is not a number
tc = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df[tc.isnull()][['customerid', 'totalcharges']]
# Out:
#       customerid totalcharges
# 488   4472-lvygi            _
# 753   3115-czmzd            _
# 936   5709-lvoeq            _
# 1082  4367-nuyao            _
# 1340  1371-dwpaz            _
# 3331  7644-omvmy            _
# 3826  3213-vvolg            _
# 4380  2520-sgtta            _
# 5218  2923-arzlg            _
# 6670  4075-wkniu            _
# 6754  2775-sefee            _

# %%
# Finding the missing values and filling them with 0s
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')
df.totalcharges.fillna(0)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: totalcharges, Length: 7043, dtype: float64

# %%
df.churn
# Out:
# 0        no
# 1        no
# 2       yes
# 3        no
# 4       yes
#        ...
# 7038     no
# 7039     no
# 7040     no
# 7041    yes
# 7042     no
# Name: churn, Length: 7043, dtype: object

# %%
# Looking at values as True or False
(df.churn == 'yes').head()

# Replacing Yes and No with 1 and 0
df.churn = (df.churn == 'yes').astype(int)

# %% [markdown]
# ### 3.3 Validation framework

# %%
# Importing SciKit learn packages to be used
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

# %%
len(df_full_train), len(df_test)
# Out:
# (5634, 1409)

# %%
# Test size is bigger because we now get a part of 80% of total data
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (4225, 1409, 1409)

# %%
# Reseting the index of datasets
df_val = df_val.reset_index(drop=True)
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
# Defining what values we need to predict
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
# Deleting the value to predict to avoid using it in the model
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %% [markdown]
# ### 3.4 Exploratory data analysis

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
# Looking for missing values
df_full_train.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        8
# churn               0
# dtype: int64

# %%
# Distribution of the value
df_full_train.churn.value_counts(normalize=True) # Using percentages
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
# We can calculate mean to find the churn rate
global_churn_rate = df_full_train.churn.mean()
round(global_churn_rate, 2)
# Out:
# np.float64(0.27)

# %%
# Look at categorical variables
df_full_train.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
# Creating a list of all numerical values
numerical = ['tenure', 'monthlycharges', 'totalcharges']

# %%
df_full_train.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
# List of categorical variables
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents',
        'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']

# %%
# Looking at only categorical variables
df_full_train[categorical]
# Out:
#       customerid  gender  seniorcitizen partner dependents phoneservice  \
# 0     5442-pptjy    male              0     yes        yes          yes
# 1     6261-rcvns  female              0      no         no          yes
# 2     2176-osjuv    male              0     yes         no          yes
# 3     6161-erdgd    male              0     yes        yes          yes
# 4     2364-ufrom    male              0      no         no          yes
# ...          ...     ...            ...     ...        ...          ...
# 5629  0781-lkxbr    male              1      no         no          yes
# 5630  3507-gasnp    male              0      no        yes          yes
# 5631  8868-wozgu    male              0      no         no          yes
# 5632  1251-krreg    male              0      no         no          yes
# 5633  5840-nvdcg  female              0     yes        yes          yes
#
#      multiplelines internetservice       onlinesecurity         onlinebackup  \
# ...

# %%
# Checking how many unique values there are in each category
df_full_train[categorical].nunique()
# Out:
# customerid          5634
# gender                 2
# seniorcitizen          2
# partner                2
# dependents             2
# phoneservice           2
# multiplelines          3
# internetservice        3
# onlinesecurity         3
# onlinebackup           3
# deviceprotection       3
# techsupport            3
# streamingtv            3
# streamingmovies        3
# contract               3
# paperlessbilling       2
# paymentmethod          4
# dtype: int64

# %% [markdown]
# ### 3.5 Feature importance: Churn rate and risk ratio

# %%
# What groups of people are there? Can we look at the churn rate for separate groups instead of globally?
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  5442-pptjy    male              0     yes        yes      12          yes
# 1  6261-rcvns  female              0      no         no      42          yes
# 2  2176-osjuv    male              0     yes         no      71          yes
# 3  6161-erdgd    male              0     yes        yes      71          yes
# 4  2364-ufrom    male              0      no         no      30          yes
#
#   multiplelines internetservice       onlinesecurity  ...  \
# 0            no              no  no_internet_service  ...
# 1            no             dsl                  yes  ...
# 2           yes             dsl                  yes  ...
# 3           yes             dsl                  yes  ...
# 4            no             dsl                  yes  ...
#
#       deviceprotection          techsupport          streamingtv  \
# 0  no_internet_service  no_internet_service  no_internet_service
# ...

# %%
# All female customers
churn_female = df_full_train[df_full_train.gender == 'female'].churn.mean()
churn_female
# Out:
# np.float64(0.27682403433476394)

# %%
# All male customers
churn_male = df_full_train[df_full_train.gender == 'male'].churn.mean()
churn_male
# Out:
# np.float64(0.2632135306553911)

# %%
# Customers with partners
churn_partner_yes = df_full_train[df_full_train.partner == 'yes'].churn.mean()
churn_partner_yes
# Out:
# np.float64(0.20503330866025166)

# %%
# Customers without partners
churn_partner_no = df_full_train[df_full_train.partner == 'no'].churn.mean()
churn_partner_no
# Out:
# np.float64(0.3298090040927694)

# %%
#################################################
# Difference between Global and Group churn rate:
# < 0: more likely to churn
# > 0: less likely to churn
################################################

# %%
#################################################
# Risk ratio: Group churn / Global churn
# > 1: more likely to churn
# < 1: less likely to churn
################################################

# %% [raw]
# SELECT
#     gender,
#     AVG(churn),
#     AVG(churn) - global_churn AS diff,
#     AVG(churn) / global_churn AS risk
# FROM
#     data
# GROUP BY
#     gender;

# %%
# Implementing the query from above in pandas
df_group = df_full_train.groupby('gender').churn.agg(['mean', 'count'])
# Adding columns manually for AVG values manually
df_group['diff'] = df_group['mean'] - global_churn_rate
df_group['risk'] = df_group['mean'] / global_churn_rate
df_group
# Out:
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980

# %%
# Using a function to display df_group from the lopp
from IPython.display import display

# %%
# Implementing the same for all categorical variables, not just gender
for c in categorical:
    # Implementing the query from above in pandas
    df_group = df_full_train.groupby(c).churn.agg(['mean', 'count'])
    # Adding columns manually for AVG values manually
    df_group['diff'] = df_group['mean'] - global_churn_rate
    df_group['risk'] = df_group['mean'] / global_churn_rate
    display(df_group)
    print()
    print()
# Out:
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
#                       mean  count      diff      risk
# multiplelines
# no                0.257407   2700 -0.012561  0.953474
# no_phone_service  0.241316    547 -0.028652  0.893870
# ...

# %% [markdown]
# ### 3.6 Mutual information

# %%
# Importing a function from SciKit learn that implements MI
from sklearn.metrics import mutual_info_score

# %%
# The valueis big, so it is important
mutual_info_score(df_full_train.contract, df_full_train.churn)
# Out:
# 0.0983203874041556

# %%
# The order of variables does not matter
mutual_info_score(df_full_train.churn, df_full_train.contract)
# Out:
# 0.0983203874041556

# %%
# The value is small, so it is not important
mutual_info_score(df_full_train.gender, df_full_train.churn)
# Out:
# 0.0001174846211139946

# %%
# Creating the function to learn which ones are more important
def mutual_info_churn_score(series):
    return mutual_info_score(series, df_full_train.churn)

# %%
# Applying the defined function to only categorical variables
mi = df_full_train[categorical].apply(mutual_info_churn_score)
mi.sort_values(ascending=False)
# Out:
# contract            0.098320
# onlinesecurity      0.063085
# techsupport         0.061032
# internetservice     0.055868
# onlinebackup        0.046923
# deviceprotection    0.043453
# paymentmethod       0.043210
# streamingtv         0.031853
# streamingmovies     0.031581
# paperlessbilling    0.017589
# dependents          0.012346
# partner             0.009968
# seniorcitizen       0.009410
# multiplelines       0.000857
# phoneservice        0.000229
# gender              0.000117
# dtype: float64

# %% [markdown]
# ### 3.7 Correlation

# %%
df_full_train.tenure.max()
# Out:
# np.int64(72)

# %%
# Calculating correlation coefficient of each numerical value and churn
df_full_train[numerical].corrwith(df_full_train.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.197416
# dtype: float64

# %%
# Selecting people who are with the company for less than 2 months and calculating their churn rate
df_full_train[df_full_train.tenure <= 2].churn.mean()
# Out:
# np.float64(0.5953420669577875)

# %%
# Between 2 and 12 months
df_full_train[(df_full_train.tenure > 2) & (df_full_train.tenure <= 12)].churn.mean()
# Out:
# np.float64(0.3994413407821229)

# %%
# More than 12 months
df_full_train[(df_full_train.tenure > 12)].churn.mean()
# Out:
# np.float64(0.17634908339788277)

# %%
# Less than 20 dollars paying per month
df_full_train[(df_full_train.monthlycharges <= 20)].churn.mean()
# Out:
# np.float64(0.08795411089866156)

# %%
# Between 20 and 50 dollars
df_full_train[(df_full_train.monthlycharges > 20) & (df_full_train.monthlycharges <= 50)].churn.mean()
# Out:
# np.float64(0.18340943683409436)

# %%
# More than 50 dollars
df_full_train[(df_full_train.monthlycharges > 50)].churn.mean()
# Out:
# np.float64(0.32499341585462205)

# %% [markdown]
# ### 3.8 One-Hot Encoding
