# %% [markdown]
# ### 6.1 Credit risk scoring project

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 6.2 Data cleaning and preparation

# %%
# Download data
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv'
# !wget $data -O 05-credit-scoring-data.csv
# Out:
# --2025-11-06 00:01:48--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182489 (178K) [text/plain]
# Saving to: ‘05-credit-scoring-data.csv’
#
# 05-credit-scoring-d 100%[===================>] 178.21K   850KB/s    in 0.2s
#
# 2025-11-06 00:01:49 (850 KB/s) - ‘05-credit-scoring-data.csv’ saved [182489/182489]

# %%
# !head 05-credit-scoring-data.csv
# Out:
# "Status","Seniority","Home","Time","Age","Marital","Records","Job","Expenses","Income","Assets","Debt","Amount","Price"
# 1,9,1,60,30,2,1,3,73,129,0,0,800,846
# 1,17,1,60,58,3,1,1,48,131,0,0,1000,1658
# 2,10,2,36,46,2,2,3,90,200,3000,0,2000,2985
# 1,0,1,60,24,1,1,1,63,182,2500,0,900,1325
# 1,0,1,36,26,1,1,1,46,107,0,0,310,910
# 1,1,2,60,36,2,1,1,75,214,3500,0,650,1645
# 1,29,2,60,44,2,1,1,75,125,10000,0,1600,1800
# 1,9,5,12,27,1,1,1,35,80,0,0,200,1093
# 1,0,2,60,32,2,1,3,90,107,15000,0,1200,1957

# %%
df = pd.read_csv(data)
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
# Turn columns into lower case
df.columns = df.columns.str.lower()
df.head()
# Out:
#    status  seniority  home  time  age  marital  records  job  expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
# Mapping each value of Status to a categorical variable - taken from the original dataset
status_values = {
    1: "ok",
    2: "default",
    0: "unknown"
}
df.status = df.status.map(status_values)
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
# Doing similar work for other values that are categorical but use numbers
home_values = {
    1: "rent",
    2: "owner",
    3: "private",
    4: "ignore",
    5: "parents",
    6: "other",
    0: "unknown"
    }

df.home = df.home.map(home_values)

marital_status = {
    1: "single",
    2: "married",
    3: "widow",
    4: "separated",
    5: "divorced",
    0: "unknown"
}

df.marital = df.marital.map(marital_status)

records_values = {
    1: "no",
    2: "yes",
    0: "unknown"
}

df.records = df.records.map(records_values)

job_values = {
    1: "fixed",
    2: "partime",
    3: "freelance",
    4: "others",
    0: "unknown"
}

df.job = df.job.map(job_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %%
# Replacing specific numbers

for c in ["income", "assets", "debt"]:
    df[c] = df[c].replace(to_replace=99999999, value=np.nan).max()

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4455.0    4455.0   4455.0  4455.0
# mean         8.0    46.0    37.0      56.0   959.0  300000.0  30000.0  1039.0
# std          8.0    15.0    11.0      20.0     0.0       0.0      0.0   475.0
# min          0.0     6.0    18.0      35.0   959.0  300000.0  30000.0   100.0
# 25%          2.0    36.0    28.0      35.0   959.0  300000.0  30000.0   700.0
# 50%          5.0    48.0    36.0      51.0   959.0  300000.0  30000.0  1000.0
# 75%         12.0    60.0    45.0      72.0   959.0  300000.0  30000.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# unknown       1
# Name: count, dtype: int64

# %%
# Filtering out unknown records
df = df[df.status != "unknown"].reset_index(drop=True)
df
# Out:
#        status  seniority   home  time  age  marital records        job  \
# 0          ok          9   rent    60   30  married      no  freelance
# 1          ok         17   rent    60   58    widow      no      fixed
# 2     default         10  owner    36   46  married     yes  freelance
# 3          ok          0   rent    60   24   single      no      fixed
# 4          ok          0   rent    36   26   single      no      fixed
# ...       ...        ...    ...   ...  ...      ...     ...        ...
# 4449  default          1   rent    60   39  married      no      fixed
# 4450       ok         22  owner    60   46  married      no      fixed
# 4451  default          0  owner    24   37  married      no    partime
# 4452       ok          0   rent    48   23   single      no  freelance
# 4453       ok          5  owner    60   32  married      no  freelance
#
#       expenses  income    assets     debt  amount  price
# 0           73   959.0  300000.0  30000.0     800    846
# ...

# %%
# Splitting the data frame
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
# Remove the default variable
y_train = (df_train.status == "default").astype("int").values
y_val = (df_val.status == "default").astype("int").values
y_test = (df_test.status == "default").astype("int").values

del df_train['status']
del df_test['status']
del df_val['status']

# %%
# Final look
df_train
# Out:
#       seniority     home  time  age  marital records        job  expenses  \
# 0            10    owner    36   36  married      no  freelance        75
# 1             6  parents    48   32   single     yes      fixed        35
# 2             1  parents    48   40  married      no      fixed        75
# 3             1  parents    48   23   single      no    partime        35
# 4             5    owner    36   46  married      no  freelance        60
# ...         ...      ...   ...  ...      ...     ...        ...       ...
# 2667         18  private    36   45  married      no      fixed        45
# 2668          7  private    60   29  married      no      fixed        60
# 2669          1  parents    24   19   single      no      fixed        35
# 2670         15    owner    48   43  married      no  freelance        60
# 2671         12    owner    48   27  married     yes      fixed        45
#
#       income    assets     debt  amount  price
# ...

# %% [markdown]
# ### 6.3 Decision trees

# %% [markdown]
# ![image.png](attachment:16d1868e-c7de-4b22-9160-f2c3ccd807d1.png)

# %%
# Simple decision tree in Python
def assess_risk(client):
    if client['records'] == 'yes':
        if client['job'] == 'partime':
            return 'default'
        else:
            return 'ok'
    else:
        if client['assets'] > 6000:
            return 'ok'
        else:
            return 'default'

# %%
# Checking the first client
xi = df_train.iloc[0].to_dict()
xi
# Out:
# {'seniority': 10,
#  'home': 'owner',
#  'time': 36,
#  'age': 36,
#  'marital': 'married',
#  'records': 'no',
#  'job': 'freelance',
#  'expenses': 75,
#  'income': 959.0,
#  'assets': 300000.0,
#  'debt': 30000.0,
#  'amount': 1000,
#  'price': 1400}

# %%
assess_risk(xi)
# Out:
# 'ok'

# %%
# Using SKLearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train.fillna(0).to_dict(orient='records')

# Train dict vectoriser
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

# %%
# Train the decision tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Testing the dataset
val_dicts = df_val.fillna(0).to_dict(orient='records')
X_val = dv.transform(val_dicts)

y_pred = dt.predict_proba(X_val)[:, 1] # Getting only the first column

# %%
# ROC curve
from sklearn.metrics import roc_auc_score

roc_auc_score(y_val, y_pred)
# Out:
# 0.6255600494054394

# %%
# Checking on training dataset
y_pred = dt.predict_proba(X_train)[:, 1] # Getting only the first column
roc_auc_score(y_train, y_pred)
# Out:
# 1.0

# %% [markdown]
# This is an example of overfitting. This might happen if our tree is too deep - it learns data for specific customers instead of trying to predict. Solution: restrict the depth of the tree

# %% [markdown]
# ![image.png](attachment:5ae7172b-f571-4acd-b2a1-c770fe839be0.png)

# %%
# Retrain
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = dt.predict_proba(X_train)[:, 1] # Getting only the first column
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)
y_pred = dt.predict_proba(X_val)[:, 1] # Getting only the first column
auc = roc_auc_score(y_val, y_pred)
print('val:', auc)
# Out:
# train: 0.7717970114359753
# val: 0.7128278559492383

# %% [markdown]
# ![image.png](attachment:880d0316-1a54-4c9f-bc27-a7fb9238416f.png)

# %%
# Checking what is inside of a tree
from sklearn.tree import export_text
print(export_text(dt))
# Out:
# |--- feature_26 <= 0.50
# |   |--- feature_16 <= 0.50
# |   |   |--- feature_27 <= 5.50
# |   |   |   |--- class: 0
# |   |   |--- feature_27 >  5.50
# |   |   |   |--- class: 0
# |   |--- feature_16 >  0.50
# |   |   |--- feature_24 <= 1049.00
# |   |   |   |--- class: 1
# |   |   |--- feature_24 >  1049.00
# |   |   |   |--- class: 1
# |--- feature_26 >  0.50
# |   |--- feature_27 <= 6.50
# |   |   |--- feature_1 <= 862.50
# |   |   |   |--- class: 0
# |   |   |--- feature_1 >  862.50
# |   |   |   |--- class: 1
# |   |--- feature_27 >  6.50
# |   |   |--- feature_28 <= 15.00
# |   |   |   |--- class: 0
# |   |   |--- feature_28 >  15.00
# |   |   |   |--- class: 0

# %%
# Using readable labels
print(export_text(dt, feature_names=dv.get_feature_names_out()))
# Out:
# |--- records=yes <= 0.50
# |   |--- job=partime <= 0.50
# |   |   |--- seniority <= 5.50
# |   |   |   |--- class: 0
# |   |   |--- seniority >  5.50
# |   |   |   |--- class: 0
# |   |--- job=partime >  0.50
# |   |   |--- price <= 1049.00
# |   |   |   |--- class: 1
# |   |   |--- price >  1049.00
# |   |   |   |--- class: 1
# |--- records=yes >  0.50
# |   |--- seniority <= 6.50
# |   |   |--- amount <= 862.50
# |   |   |   |--- class: 0
# |   |   |--- amount >  862.50
# |   |   |   |--- class: 1
# |   |--- seniority >  6.50
# |   |   |--- time <= 15.00
# |   |   |   |--- class: 0
# |   |   |--- time >  15.00
# |   |   |   |--- class: 0

# %% [markdown]
# ### 6.4 Decision tree learning algorithm

# %%
# Simple example
data = [
    [8000, 'default'],
    [2000, 'default'],
    [0, 'default'],
    [5000, 'ok'],
    [5000, 'ok'],
    [4000, 'ok'],
    [9000, 'ok'],
    [3000, 'default'],
]

df_example = pd.DataFrame(data, columns=['assets', 'status'])
df_example
# Out:
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# 7    3000  default

# %% [markdown]
# ![image.png](attachment:eee9d9dd-c50b-4916-b352-ce6cb252e321.png)

# %%
# Sort the dataset
df_example.sort_values('assets')
# Out:
#    assets   status
# 2       0  default
# 1    2000  default
# 7    3000  default
# 5    4000       ok
# 4    5000       ok
# 3    5000       ok
# 0    8000  default
# 6    9000       ok

# %% [markdown]
# ![image.png](attachment:97184455-4ca5-4503-aa10-86a1e86b39f8.png)

# %%
# Potential threasholds
Ts = [2000, 3000, 4000, 5000, 8000]

# %%
from IPython.display import display

for T in Ts:
    print(T)
    df_left = df_example[df_example.assets <= T]
    df_right = df_example[df_example.assets > T]

    display(df_left)
    print(df_left.status.value_counts(normalize=True))
    display(df_right)
    print(df_right.status.value_counts(normalize=True))
# Out:
# 2000
#    assets   status
# 1    2000  default
# 2       0  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# 7    3000  default
# status
# ok         0.666667
# default    0.333333
# Name: proportion, dtype: float64
# 3000
#    assets   status
# 1    2000  default
# 2       0  default
# 7    3000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# status
# ok         0.8
# default    0.2
# Name: proportion, dtype: float64
# 4000
#    assets   status
# 1    2000  default
# 2       0  default
# 5    4000       ok
# 7    3000  default
# status
# default    0.75
# ok         0.25
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# ...

# %% [markdown]
# The next step is to decide which split is the best

# %% [markdown]
# ![image.png](attachment:6ffec9d3-0f69-40ca-99d1-e721568e14d1.png)

# %% [markdown]
# ![image.png](attachment:93153dfb-6b0a-4711-8dfe-3313e7566282.png)

# %%
# Using two features
data = [
    [8000, 3000, 'default'],
    [2000, 1000, 'default'],
    [0, 1000, 'default'],
    [5000, 1000, 'ok'],
    [5000, 1000, 'ok'],
    [4000, 1000, 'ok'],
    [9000, 500, 'ok'],
    [3000, 2000, 'default'],
]

df_example = pd.DataFrame(data, columns=['assets', 'debt', 'status'])
df_example
# Out:
#    assets  debt   status
# 0    8000  3000  default
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default

# %%
# Sort the dataset
df_example.sort_values('debt')
# Out:
#    assets  debt   status
# 6    9000   500       ok
# 1    2000  1000  default
# 3    5000  1000       ok
# 2       0  1000  default
# 5    4000  1000       ok
# 4    5000  1000       ok
# 7    3000  2000  default
# 0    8000  3000  default

# %%
# Defining thresholds for both features
thresholds = {
    'assets': [2000, 3000, 4000, 5000, 8000],
    'debt': [500, 1000, 2000]
}

for feature, Ts, in thresholds.items():
    print('################################')
    print(feature)
    for T in Ts:
        print(T)
        df_left = df_example[df_example[feature] <= T]
        df_right = df_example[df_example[feature] > T]
    
        display(df_left)
        print(df_left.status.value_counts(normalize=True))
        display(df_right)
        print(df_right.status.value_counts(normalize=True))

        print()
    print('################################')
# Out:
# ################################
# assets
# 2000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default
# status
# ok         0.666667
# default    0.333333
# Name: proportion, dtype: float64
#
# 3000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 7    3000  2000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# status
# ok         0.8
# default    0.2
# Name: proportion, dtype: float64
#
# 4000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# ...

# %% [markdown]
# ![image.png](attachment:30e58161-6005-40de-82de-72cd3f5a3311.png)

# %% [markdown]
# ![image.png](attachment:7e7e688d-73a5-42eb-8e0b-01b5f0962dad.png)

# %% [markdown]
# ![image.png](attachment:cee727bc-060a-428d-8615-b64f505321ea.png)

# %% [markdown]
# ### 6.5 Decision Tree Parameter Tuning

# %%
for d in [1, 2, 3, 4, 5, 6, 10, 15, 20, None]:
    dt = DecisionTreeClassifier(max_depth=d)
    dt.fit(X_train, y_train)

    y_pred = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)

    print('%4s -> %.3f' % (d, auc))
# Out:
#    1 -> 0.606
#    2 -> 0.669
#    3 -> 0.713
#    4 -> 0.719
#    5 -> 0.738
#    6 -> 0.746
#   10 -> 0.677
#   15 -> 0.644
#   20 -> 0.642
# None -> 0.626
